# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['admin',
#  'autosaurus',
#  'classDB',
#  'config',
#  'epa',
#  'fruitdb',
#  'gardenDB',
#  'local',
#  'met',
#  'petsitly_marketing',
#  'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
# review a document in the establishments collection

# %%
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'West Cottage',
#  'AddressLine2': 'South Foreland Lighthouse',
#  'AddressLine3': 'The Front',
#  'AddressLine4': 'St Margarets Bay',
#  'BusinessName': 'Mrs Knotts Tea Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.492467848017,
#  'FHRSID': 429991,
#  'LocalAuthorityBusinessID': 'PI/000055200',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6HP',
#  'RatingDate': '2019-05-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('648e17b02a12d71b4372fbf5'),
#  'geocode': {'latitude': '51.14061', 'longitude': '1.371894'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/429991',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
newhalal = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(newhalal)

# %%
# Check that the new restaurant was inserted
newrest = list(establishments.find(newhalal))
newrest
# Out:
# [{'_id': ObjectId('648e17bc979606a0d7160937'),
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'PostCode': 'SE18 7DY',
#   'Phone': '',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#   'RightToReply': '',
#   'Distance': 4623.972328074718,
#   'NewRatingPending': True}]

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
#list(establishments.find_one({"BusinessType":"Restaurant/Cafe/Canteen"}))

# %%
list(establishments.find({"BusinessType":"Restaurant/Cafe/Canteen"}))
# Out:
# [{'_id': ObjectId('648e17b02a12d71b4372fbf5'),
#   'FHRSID': 429991,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000055200',
#   'BusinessName': 'Mrs Knotts Tea Room',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'West Cottage',
#   'AddressLine2': 'South Foreland Lighthouse',
#   'AddressLine3': 'The Front',
#   'AddressLine4': 'St Margarets Bay',
#   'PostCode': 'CT15 6HP',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-05-02T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.371894', 'latitude': '51.14061'},
#   'RightToReply': '',
#   'Distance': 4587.492467848017,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/429991'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fbf6'),
#   'FHRSID': 551803,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000070948',
#   'BusinessName': 'The Tea Room',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'The Pines Garden',
#   'AddressLine2': 'Beach Road',
#   'AddressLine3': 'St Margarets Bay',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6DZ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-08-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.383298', 'latitude': '51.148133'},
#   'RightToReply': '',
#   'Distance': 4587.362402580997,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/551803'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fbf7'),
#   'FHRSID': 1531040,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000085904',
#   'BusinessName': 'The Halfway Hut',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Walmer And Kingsdown Golf Club',
#   'AddressLine2': 'The Leas',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EP',
#   'Phone': '',
#   'RatingValue': 'AwaitingInspection',
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingDate': '1901-01-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.4032986', 'latitude': '51.1787284'},
#   'RightToReply': '',
#   'Distance': 4587.792282474894,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1531040'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fbf9'),
#   'FHRSID': 254719,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000069980',
#   'BusinessName': 'Refreshment Kiosk',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'The Bay',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-03-24T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#   'RightToReply': '',
#   'Distance': 4587.347174863443,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254719'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fbfc'),
#   'FHRSID': 1273080,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000082753',
#   'BusinessName': 'Lovetocater',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Walmer And Kingsdown Golf Club',
#   'AddressLine2': 'The Leas',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EP',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-06-23T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.4032986', 'latitude': '51.1787284'},
#   'RightToReply': '',
#   'Distance': 4587.792282474894,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1273080'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc01'),
#   'FHRSID': 429982,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000043978',
#   'BusinessName': 'The Barn',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Reach Court Farm',
#   'AddressLine2': 'Reach Road',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6AQ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2017-09-21T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.371115', 'latitude': '51.147379'},
#   'RightToReply': '',
#   'Distance': 4587.77622109052,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/429982'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc02'),
#   'FHRSID': 1349980,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000084064',
#   'BusinessName': 'Boodles',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '3 The Droveway',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DH',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-06-14T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.378536', 'latitude': '51.150879'},
#   'RightToReply': '',
#   'Distance': 4587.638929767669,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1349980'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc03'),
#   'FHRSID': 1290215,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000083029',
#   'BusinessName': 'FirstLight Bar & Café',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '1 The Droveway',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DH',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-11-09T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.378231', 'latitude': '51.150625'},
#   'RightToReply': '',
#   'Distance': 4587.64041272672,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1290215'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc05'),
#   'FHRSID': 466211,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000070896',
#   'BusinessName': 'The White Cliffs',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'High Street',
#   'AddressLine2': 'St Margarets At Cliffe',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6AT',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-12-03T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.372341', 'latitude': '51.153784'},
#   'RightToReply': '',
#   'Distance': 4587.973462119751,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/466211'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc07'),
#   'FHRSID': 254239,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000068711',
#   'BusinessName': 'Boat House & Langdon',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'St Margarets Hotel And Country Club',
#   'AddressLine2': 'Reach Road',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6AG',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-07-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.366199', 'latitude': '51.150372'},
#   'RightToReply': '',
#   'Distance': 4588.067654106012,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254239'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc09'),
#   'FHRSID': 1376311,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000084109',
#   'BusinessName': "St Margaret's Bowls and Social Club",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Bowling Club',
#   'AddressLine2': '13 Kingsdown Road',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6AZ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-07-13T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.37213003635406', 'latitude': '51.1558113098145'},
#   'RightToReply': '',
#   'Distance': 4588.057641902885,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1376311'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc0b'),
#   'FHRSID': 760657,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000074489',
#   'BusinessName': 'The Lounge Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Kingsdown Park Holiday Village',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EU',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2017-08-11T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.402478', 'latitude': '51.185258'},
#   'RightToReply': '',
#   'Distance': 4588.0687557014535,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/760657'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc0f'),
#   'FHRSID': 254390,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000038162',
#   'BusinessName': 'National Trust White Cliffs',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Visitors Centre',
#   'AddressLine2': 'National Trust',
#   'AddressLine3': 'Langdon Cliffs',
#   'AddressLine4': 'Dover',
#   'PostCode': 'CT16 1HJ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-11-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.338963', 'latitude': '51.132101'},
#   'RightToReply': '',
#   'Distance': 4588.367605738605,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254390'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc14'),
#   'FHRSID': 452084,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000024319',
#   'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Berth 8/9',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2017-11-14T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/452084'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc18'),
#   'FHRSID': 452096,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000053923',
#   'BusinessName': 'Burger King',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Terminal 3',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-11-14T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/452096'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc26'),
#   'FHRSID': 435288,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000029521',
#   'BusinessName': 'Table Table at Premier Inn',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Marine Court',
#   'AddressLine2': 'Marine Parade',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1LW',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-24T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.320811', 'latitude': '51.12518'},
#   'RightToReply': '',
#   'Distance': 4588.766337962921,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/435288'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc28'),
#   'FHRSID': 365194,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000016869',
#   'BusinessName': 'Walmer Castle Tea Rooms',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Walmer Castle',
#   'AddressLine2': 'Kingsdown Road',
#   'AddressLine3': 'Walmer',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 7LJ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-04-25T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.401177', 'latitude': '51.200812'},
#   'RightToReply': '',
#   'Distance': 4588.703665769568,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/365194'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc2a'),
#   'FHRSID': 429958,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000021477',
#   'BusinessName': 'Food Outlets',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Dover Castle',
#   'AddressLine2': 'Castle Hill Road',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1HU',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-03-21T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.321281', 'latitude': '51.127343'},
#   'RightToReply': '',
#   'Distance': 4588.830773120301,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/429958'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc2b'),
#   'FHRSID': 254674,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000070994',
#   'BusinessName': 'The Dover Patrol Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Esplanade',
#   'AddressLine2': 'Dover',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT17 9FS',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-11-04T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31350600719452', 'latitude': '51.120418548584'},
#   'RightToReply': '',
#   'Distance': 4588.852448951688,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254674'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc2d'),
#   'FHRSID': 944717,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077121',
#   'BusinessName': 'GCP Catering Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Freight Clearance Centre',
#   'AddressLine2': 'Lord Warden Square',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT17 9DN',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-01-08T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.309674', 'latitude': '51.115969'},
#   'RightToReply': '',
#   'Distance': 4588.824127379671,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/944717'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc32'),
#   'FHRSID': 1197079,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000081114',
#   'BusinessName': 'Port of Dover Cargo Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Harbour House',
#   'AddressLine2': 'Waterloo Crescent',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT17 9BU',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-04-29T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31319499015808', 'latitude': '51.121021270752'},
#   'RightToReply': '',
#   'Distance': 4588.886464589285,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1197079'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc33'),
#   'FHRSID': 1290149,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000079670',
#   'BusinessName': 'Places Leisure',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Dover Leisure Centre',
#   'AddressLine2': 'Townwall Street',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': '',
#   'Phone': '',
#   'RatingValue': 'AwaitingInspection',
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingDate': '1901-01-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31893503375069', 'latitude': '51.1253842651865'},
#   'RightToReply': '',
#   'Distance': 4588.842219938546,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1290149'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc34'),
#   'FHRSID': 1501285,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000085551',
#   'BusinessName': 'The Pedaler on the Port',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Harbour House',
#   'AddressLine2': 'Waterloo Crescent',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT17 9BU',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-07-19T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31319499015808', 'latitude': '51.121021270752'},
#   'RightToReply': '',
#   'Distance': 4588.886464589285,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1501285'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc36'),
#   'FHRSID': 254330,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000068893',
#   'BusinessName': 'Dover Marina Hotel',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Dover Marina Hotel And Spa',
#   'AddressLine2': 'Waterloo Crescent',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT17 9BP',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-24T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31420302391052', 'latitude': '51.122127532959'},
#   'RightToReply': '',
#   'Distance': 4588.891502846812,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254330'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc37'),
#   'FHRSID': 1379005,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000084277',
#   'BusinessName': "Wheeler's Fish & Chips",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Dover Marina Hotel And Spa',
#   'AddressLine2': 'Waterloo Crescent',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT17 9BP',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-24T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31420302391052', 'latitude': '51.122127532959'},
#   'RightToReply': '',
#   'Distance': 4588.891502846812,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1379005'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc38'),
#   'FHRSID': 1379004,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000084276',
#   'BusinessName': "Mr White's English Chophouse (DMHS)",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Dover Marina Hotel And Spa',
#   'AddressLine2': 'Waterloo Crescent',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT17 9BP',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-24T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31420302391052', 'latitude': '51.122127532959'},
#   'RightToReply': '',
#   'Distance': 4588.891502846812,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1379004'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc3d'),
#   'FHRSID': 1217588,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000081902',
#   'BusinessName': 'Boardwalk Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'De Bradelei Wharf',
#   'AddressLine2': 'Cambridge Road',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT17 9BJ',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-03-08T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.313783', 'latitude': '51.122456'},
#   'RightToReply': '',
#   'Distance': 4588.919147529032,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1217588'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc3e'),
#   'FHRSID': 429957,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000021274',
#   'BusinessName': 'Cullins Yard',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Cambridge Road',
#   'AddressLine2': 'Dover',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT17 9BY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-01-27T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.313152', 'latitude': '51.121025'},
#   'RightToReply': '',
#   'Distance': 4588.888167906964,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/429957'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc3f'),
#   'FHRSID': 1206789,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000081718',
#   'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Unit 20',
#   'AddressLine2': 'St James',
#   'AddressLine3': 'St James Street',
#   'AddressLine4': 'Dover',
#   'PostCode': 'CT16 1QD',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-24T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31710195541382', 'latitude': '51.1258888244629'},
#   'RightToReply': '',
#   'Distance': 4588.927859759881,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1206789'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc40'),
#   'FHRSID': 1206788,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000081717',
#   'BusinessName': 'Costa Coffee, Next',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Unit 9',
#   'AddressLine2': 'St James',
#   'AddressLine3': 'St James Street',
#   'AddressLine4': 'Dover',
#   'PostCode': 'CT16 1QD',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-24T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.3170979', 'latitude': '51.1258217'},
#   'RightToReply': '',
#   'Distance': 4588.925477692847,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1206788'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc44'),
#   'FHRSID': 1055031,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078244',
#   'BusinessName': 'Nandos',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Unit 4',
#   'AddressLine2': 'St James',
#   'AddressLine3': 'St James Street',
#   'AddressLine4': 'Dover',
#   'PostCode': 'CT16 1QD',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-04-23T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31710195541382', 'latitude': '51.1258888244629'},
#   'RightToReply': '',
#   'Distance': 4588.927859759881,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1055031'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc47'),
#   'FHRSID': 1055032,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078264',
#   'BusinessName': 'Marks and Spencer Dover Simply Food',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Unit 17',
#   'AddressLine2': 'St James',
#   'AddressLine3': 'St James Street',
#   'AddressLine4': 'Dover',
#   'PostCode': 'CT16 1QD',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-04-29T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31710195541382', 'latitude': '51.1258888244629'},
#   'RightToReply': '',
#   'Distance': 4588.927859759881,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1055032'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc49'),
#   'FHRSID': 1130699,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000080857',
#   'BusinessName': 'Kaspas',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Unit 3',
#   'AddressLine2': 'St James',
#   'AddressLine3': 'St James Street',
#   'AddressLine4': 'Dover',
#   'PostCode': 'CT16 1QD',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-05-06T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31710195541382', 'latitude': '51.1258888244629'},
#   'RightToReply': '',
#   'Distance': 4588.927859759881,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1130699'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc4d'),
#   'FHRSID': 1420222,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075298',
#   'BusinessName': 'Rico Sabor',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Unit 18',
#   'AddressLine2': 'St James',
#   'AddressLine3': 'St James Street',
#   'AddressLine4': 'Dover',
#   'PostCode': 'CT16 1QD',
#   'Phone': '',
#   'RatingValue': '3',
#   'RatingKey': 'fhrs_3_en-gb',
#   'RatingDate': '2022-02-03T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.3162446', 'latitude': '51.1251847'},
#   'RightToReply': '',
#   'Distance': 4588.93248882499,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1420222'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc4e'),
#   'FHRSID': 920544,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000076461',
#   'BusinessName': 'Cinnamon Island',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '1 Cambridge Terrace',
#   'AddressLine2': 'Dover',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT16 1JT',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-06-16T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.314114', 'latitude': '51.123283'},
#   'RightToReply': '',
#   'Distance': 4588.938276148026,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/920544'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc51'),
#   'FHRSID': 1514902,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000085566',
#   'BusinessName': 'Taco Bell',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Unit 2',
#   'AddressLine2': 'St James',
#   'AddressLine3': 'St James Street',
#   'AddressLine4': 'Dover',
#   'PostCode': 'CT16 1QD',
#   'Phone': '',
#   'RatingValue': 'AwaitingInspection',
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingDate': '1901-01-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.31710195541382', 'latitude': '51.1258888244629'},
#   'RightToReply': '',
#   'Distance': 4588.927859759881,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1514902'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc57'),
#   'FHRSID': 1376313,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000084111',
#   'BusinessName': 'IL RUSTICO',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '4 Bench Street',
#   'AddressLine2': 'Dover',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT16 1JH',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-07-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.313711', 'latitude': '51.124041'},
#   'RightToReply': '',
#   'Distance': 4588.981486191326,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1376313'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc59'),
#   'FHRSID': 1531046,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000085966',
#   'BusinessName': 'German Doner Kebab',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Unit 6',
#   'AddressLine2': 'St James',
#   'AddressLine3': 'St James Street',
#   'AddressLine4': 'Dover',
#   'PostCode': 'CT16 1QD',
#   'Phone': '',
#   'RatingValue': 'AwaitingInspection',
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingDate': '1901-01-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.3154124', 'latitude': '51.1254339'},
#   'RightToReply': '',
#   'Distance': 4588.972127659764,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1531046'}]},
#  {'_id': ObjectId('648e17b02a12d71b4372fc62'),
#   'FHRSID': 254412,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000021785',
#   'BusinessName': 'Terrace Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Channel House',
#   'AddressLine2': 'Channel View Road',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT17 9TJ',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-03-08T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
# ...
#   'RightToReply': '',
#   'Distance': 4603.263191174518,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1535391'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a39'),
#   'FHRSID': 1091501,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '78403',
#   'BusinessName': 'Micro Roastery',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': "4 St Margaret's Street",
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'CT1 2TP',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-10-13T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.0789847', 'latitude': '51.2775379'},
#   'RightToReply': '',
#   'Distance': 4603.278441986052,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1091501'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a3c'),
#   'FHRSID': 1103314,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '80966',
#   'BusinessName': 'Kaspas Desserts',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '2 High Street',
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'CT1 2JH',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-03T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.08035898208618', 'latitude': '51.2789916992188'},
#   'RightToReply': '',
#   'Distance': 4603.283105213431,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1103314'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a3d'),
#   'FHRSID': 1102502,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '49937',
#   'BusinessName': 'Canterbury Open Centre',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Station Road East',
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'CT1 2RB',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-07-01T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.07567203044891', 'latitude': '51.274528503418'},
#   'RightToReply': '',
#   'Distance': 4603.285789129248,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1102502'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a40'),
#   'FHRSID': 1379960,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'CP/21/00118',
#   'BusinessName': 'Sweet Snax',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '54 Northgate',
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT1 1BE',
#   'Phone': '',
#   'RatingValue': '4',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2021-09-09T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.0843497', 'latitude': '51.2829617'},
#   'RightToReply': '',
#   'Distance': 4603.287234664165,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1379960'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a42'),
#   'FHRSID': 1421551,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'CP/21/00232',
#   'BusinessName': 'Taco Bill Street Food',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': "38 St Margaret's Street",
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT1 2TY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-10-27T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.0788315', 'latitude': '51.2778208'},
#   'RightToReply': '',
#   'Distance': 4603.294615582138,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1421551'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a45'),
#   'FHRSID': 1103315,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '81001',
#   'BusinessName': 'Pork & Co',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '27 Sun Street',
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT1 2HX',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-09-22T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.0809334', 'latitude': '51.2798702'},
#   'RightToReply': '',
#   'Distance': 4603.295217611811,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1103315'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a49'),
#   'FHRSID': 1520925,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'CP/22/00140',
#   'BusinessName': 'Teastones',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '3-4 Sun Street',
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT1 2HX',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-08-04T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.0806972', 'latitude': '51.2797201'},
#   'RightToReply': '',
#   'Distance': 4603.298158362228,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1520925'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a4a'),
#   'FHRSID': 1091479,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '54423',
#   'BusinessName': 'Chambers Of Canterbury',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '59 Palace Street',
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'CT1 2DY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-10-29T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.0810021', 'latitude': '51.2800393'},
#   'RightToReply': '',
#   'Distance': 4603.299068720673,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1091479'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a4c'),
#   'FHRSID': 1103512,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '82726',
#   'BusinessName': 'Creams Cafe',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '60-61 Palace Street',
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'CT1 2DY',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-11-07T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.0809382', 'latitude': '51.279942'},
#   'RightToReply': '',
#   'Distance': 4603.297737233644,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1103512'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a4d'),
#   'FHRSID': 1361026,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'CP/21/00074',
#   'BusinessName': 'Chuck And Blade Burgers',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '25-27 Sun Street',
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT1 2HX',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-07-27T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.0809334', 'latitude': '51.2798702'},
#   'RightToReply': '',
#   'Distance': 4603.295217611811,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1361026'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a4e'),
#   'FHRSID': 1102910,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '75036',
#   'BusinessName': 'Tamago',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '63-64 Northgate',
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'CT1 1BB',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-02-08T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.0837732', 'latitude': '51.2826557'},
#   'RightToReply': '',
#   'Distance': 4603.296672976425,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1102910'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a50'),
#   'FHRSID': 1102596,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '58708',
#   'BusinessName': 'Caffe Nero',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '44 High Street',
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'CT1 2SA',
#   'Phone': '',
#   'RatingValue': '2',
#   'RatingKey': 'fhrs_2_en-gb',
#   'RatingDate': '2021-11-10T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 15, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.0797662', 'latitude': '51.2789295'},
#   'RightToReply': '',
#   'Distance': 4603.302285738391,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1102596'}]},
#  {'_id': ObjectId('648e17b02a12d71b43730a51'),
#   'FHRSID': 1103554,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': '82971',
#   'BusinessName': 'Deakins',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '1-2 Sun Street',
#   'AddressLine2': 'Canterbury',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'PostCode': 'CT1 2HX',
#   'Phone': '',
#   'RatingValue': '5',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-09-10T00:00:00',
#   'LocalAuthorityCode': '180',
#   'LocalAuthorityName': 'Canterbury City',
#   'LocalAuthorityWebSite': 'http://www.canterbury.gov.uk',
#   'LocalAuthorityEmailAddress': ' ',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.0805975', 'latitude': '51.2797801'},
#   'RightToReply': '',
#   'Distance': 4603.304027803904,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1103554'}]},
#  ...]

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
rest = list(establishments.find({"BusinessType":"Restaurant/Cafe/Canteen"}))
restid = rest[0]["BusinessTypeID"]
restid
# Out:
# 1

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_many({"BusinessType":"Restaurant/Cafe/Canteen"},
                          {"$set":{"BusinessTypeID":restid}})

# %%
# Confirm that the new restaurant was updated
list(establishments.find({'BusinessName': 'Penang Flavours'}))
# Out:
# [{'_id': ObjectId('648e17bc979606a0d7160937'),
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'PostCode': 'SE18 7DY',
#   'Phone': '',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#   'RightToReply': '',
#   'Distance': 4623.972328074718,
#   'NewRatingPending': True}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
len(list(establishments.find({'LocalAuthorityName': 'Dover'})))
# Out:
# 994

# %%
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': 'Dover'})

# %%
# Check if any remaining documents include Dover
len(list(establishments.find({'LocalAuthorityName': 'Dover'})))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('648e17b02a12d71b4372fed9'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': '4',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.196408', 'latitude': '51.086058'},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
#.update_many({}, [])
#.update_many({}, [{"set": {}}])

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{"$set": {"geocode.longitude": {"$toDouble": "$geocode.longitude"},
                                         "geocode.latitude": {"$toDouble": "$geocode.latitude"}}}])

# %%
establishments.find_one()
# Out:
# {'_id': ObjectId('648e17b02a12d71b4372fed9'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': '4',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.196408, 'latitude': 51.086058},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
establishments.distinct("RatingValue")
# Out:
# ['0',
#  '1',
#  '2',
#  '3',
#  '4',
#  '5',
#  'Awaiting Inspection',
#  'AwaitingInspection',
#  'AwaitingPublication',
#  'Exempt',
#  'Pass']

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ { '$set': {"RatingValue" : None} } ])

# %%
establishments.distinct("RatingValue")
# Out:
# [None, '0', '1', '2', '3', '4', '5']

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{"$set": {"RatingValue": {"$toInt": "$RatingValue"}}}])

# %%
establishments.distinct("RatingValue")
# Out:
# [None, 0, 1, 2, 3, 4, 5]

# %%
# Check that the coordinates and rating value are now numbers
establishments.find_one()
# Out:
# {'_id': ObjectId('648e17b02a12d71b4372fed9'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': 4,
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.196408, 'latitude': 51.086058},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}
